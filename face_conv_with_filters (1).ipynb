# %%
import numpy as np;
import matplotlib.pyplot as plt;
from scipy import ndimage
import pandas as pd;
import os;
import tensorflow as tf
import cv2;
import time
import math
# %matplotlib inline

# %%
"""
class DataSet:
    directory = [];
    train_size = 0;
    prev = 0;
    def __init__(self):
        print (os.getcwd())
        self.directory = sorted(os.listdir("Face/"));
        self.directory.remove('.ipynb_checkpoints')
        for label in self.directory:
            self.train_size = self.train_size + len(os.listdir("Face/"+str(label)));
        print (self.train_size)
        self.count = 0
        self.image_size = 100;
    def randomize(self,dataset, labels):
        permutation = np.random.permutation(labels.shape[0])
        shuffled_dataset = dataset[permutation,:,:]
        shuffled_labels = labels[permutation]
        return shuffled_dataset, shuffled_labels
    def getData(self):
        
        temp = self.directory[self.prev:self.prev+30]
        self.prev = self.prev+31;
        print(temp)
        train_size = 0;
        for label in temp:
            train_size = train_size + len(os.listdir("Face/"+str(label)));
        
        train_data_X = np.zeros((train_size,self.image_size,self.image_size),dtype=np.float32)
        train_data_Y= np.zeros((train_size),dtype=np.int32)
        count = 0;
        
        for label in temp:
            images = os.listdir("Face/"+str(label));
            for i in images:
                img = np.array(plt.imread('Face/'+str(label)+'/'+i),dtype=float);
                train_data_X[count]=(img-img.min())/(img.max()-img.min());#normalizes the data
                train_data_Y[count] = (self.directory.index(label));
                count = count+1;
        
        train_dataset, train_labels = self.randomize(train_data_X,train_data_Y)
        
        train_size = int(train_size/100)*100
        valid_size = int(train_size/10);
        valid_size = int(valid_size/100)*100
        end = train_size;
        train_size = train_size - valid_size;
        X_train = train_dataset[0:train_size].reshape(train_size,(self.image_size**2)).astype(np.float32);
        y_train = train_labels[0:train_size][:].astype(np.int32)
        X_test = train_dataset[train_size:end].reshape(train_dataset[train_size:end].shape[0],(self.image_size**2)).astype(np.float32);
        y_test = train_labels[train_size:end][:].astype(np.int32)
        d = pd.DataFrame(np.array(X_test))
        d.to_pickle('temp/test-data'+str(self.prev)+'.pickle')
        d = pd.DataFrame(np.array(y_test))
        d.to_pickle('temp/test-labels'+str(self.prev)+'.pickle')
        return (X_train,y_train,X_test,y_test)

d = DataSet()
label_count = len(d.directory);
"""
# Out:
# '\nclass DataSet:\n    directory = [];\n    train_size = 0;\n    prev = 0;\n    def __init__(self):\n        print (os.getcwd())\n        self.directory = sorted(os.listdir("Face/"));\n        self.directory.remove(\'.ipynb_checkpoints\')\n        for label in self.directory:\n            self.train_size = self.train_size + len(os.listdir("Face/"+str(label)));\n        print (self.train_size)\n        self.count = 0\n        self.image_size = 100;\n    def randomize(self,dataset, labels):\n        permutation = np.random.permutation(labels.shape[0])\n        shuffled_dataset = dataset[permutation,:,:]\n        shuffled_labels = labels[permutation]\n        return shuffled_dataset, shuffled_labels\n    def getData(self):\n        \n        temp = self.directory[self.prev:self.prev+30]\n        self.prev = self.prev+31;\n        print(temp)\n        train_size = 0;\n        for label in temp:\n            train_size = train_size + len(os.listdir("Face/"+str(label)));\n        \n        train_data_X = np.zeros((train_size,self.image_size,self.image_size),dtype=np.float32)\n        train_data_Y= np.zeros((train_size),dtype=np.int32)\n        count = 0;\n        \n        for label in temp:\n            images = os.listdir("Face/"+str(label));\n            for i in images:\n                img = np.array(plt.imread(\'Face/\'+str(label)+\'/\'+i),dtype=float);\n                train_data_X[count]=(img-img.min())/(img.max()-img.min());#normalizes the data\n                train_data_Y[count] = (self.directory.index(label));\n                count = count+1;\n        \n        train_dataset, train_labels = self.randomize(train_data_X,train_data_Y)\n        \n        train_size = int(train_size/100)*100\n        valid_size = int(train_size/10);\n        valid_size = int(valid_size/100)*100\n        end = train_size;\n        train_size = train_size - valid_size;\n        X_train = train_dataset[0:train_size].reshape(train_size,(self.image_size**2)).astype(np.float32);\n        y_train = train_labels[0:train_size][:].astype(np.int32)\n        X_test = train_dataset[train_size:end].reshape(train_dataset[train_size:end].shape[0],(self.image_size**2)).astype(np.float32);\n        y_test = train_labels[train_size:end][:].astype(np.int32)\n        d = pd.DataFrame(np.array(X_test))\n        d.to_pickle(\'temp/test-data\'+str(self.prev)+\'.pickle\')\n        d = pd.DataFrame(np.array(y_test))\n        d.to_pickle(\'temp/test-labels\'+str(self.prev)+\'.pickle\')\n        return (X_train,y_train,X_test,y_test)\n\nd = DataSet()\nlabel_count = len(d.directory);\n'

# %%
print (os.getcwd())
directory = sorted(os.listdir("Face"));
directory.remove('.ipynb_checkpoints')
# Out:
# /home/vigneshj6/FaceProject

# %%
train_size = 0;
for label in directory:
    train_size = train_size + len(os.listdir("Face/"+str(label)));
print (train_size)
count = 0
pixel = 100; #change the pixel size if the data set changes
image_size = 100;
#Depending on the size, X(Features) and Y(Labels) get initialized to zero.
train_data_X = np.zeros((train_size,pixel,pixel),dtype=float)
#train_data_Y = np.zeros((train_size,9),dtype=float)
train_data_Y= np.zeros((train_size),dtype=np.int32)
#It loads the true values and puts it in the train_data_X and sets train_data_y=1 ;

permutation = np.random.permutation(train_size);

for label in directory:
    images = os.listdir("Face/"+str(label));
    for i in images:
        img = np.array(plt.imread('Face/'+str(label)+'/'+i),dtype=float);
        train_data_X[permutation[count]]=(img-img.min())/(img.max()-img.min());#normalizes the data
        train_data_Y[permutation[count]] = (directory.index(label));
        count = count+1
        if(count%10000==0):
            print(count)
        if(count%50000==0):
            l = permutation[count-1]
            print(train_data_Y[l],directory[train_data_Y[l]])
            plt.imshow(train_data_X[l],cmap='gray')
            plt.show()
print (train_data_X.shape)
print (train_data_Y.shape)
label_count=len(directory)
print (label_count)
total = train_size
# Out:
# /home/vigneshj6/FaceProject
# 378348
# 10000
# 20000
# 30000
# 40000
# 50000
# 179 bill gates
# 60000
# 70000
# 80000
# 90000
# 100000
# 368 del toro
# 110000
# 120000
# 130000
# 140000
# 150000
# 597 heather graham
# 160000
# 170000
# 180000
# 190000
# 200000
# 790 joseph ratzinger
# 210000
# 220000
# 230000
# 240000
# 250000
# 985 mahmoud ahmadinejad
# 260000
# 270000
# 280000
# 290000
# 300000
# 1192 pamela anderson
# 310000
# 320000
# 330000
# 340000
# 350000
# 1428 steve jobs
# 360000
# 370000
# (378348, 100, 100)
# (378348,)
# 1581

# %%
sample = range(10);
for samp in sample:
    print (directory[train_data_Y[samp]])
    plt.imshow(train_data_X[samp])
    plt.show()
# Out:
# leighton meester
# abraham lincoln
# robert downey
# don bosco
# bridget moynahan
# adrien brody
# raven symone
# lindsay lohan
# halle berry
# paz vega

# %%
train_size = int(train_size/100)*100
valid_size = int(train_size/10);
valid_size = int(valid_size/100)*100
end = train_size;
train_size = train_size - valid_size;
X_train = train_data_X[0:train_size].reshape(train_size,(image_size**2));
y_train = train_data_Y[0:train_size][:].astype(np.int32)
X_test = train_data_X[train_size:end].reshape(train_data_X[train_size:end].shape[0],(image_size**2));
y_test = train_data_Y[train_size:end][:].astype(np.int32)
print (X_train.shape)
print (y_train.shape)
print (X_test.shape)
print (y_test.shape)
# Out:
# (340500, 10000)
# (340500,)
# (37800, 10000)
# (37800,)

# %% [markdown]
# ## Hyper Parameters for CNN

# %%
label_count=len(directory)
image_size = 100
image_size_flat = image_size * image_size
image_shape = (image_size, image_size)
num_channels=1
num_labels = label_count #Currently there are 30 Labels
print(num_labels)
num_iterations = 50000
batch_size = 100
alpha = 0.001;
# Convolutional Layer 1.
filter_size1 = 5          # Convolution filters are 5 x 5 pixels.
num_filters1 = 16         # There are 16 of these filters.
conv_stride1=[1,1,1,1]
# Convolutional Layer 2.
filter_size2 = 4          # Convolution filters are 4 x 4 pixels.
num_filters2 = 32         # There are 32 of these filters.
conv_stride2=[1,1,1,1]
# Convolutional Layer 3.
filter_size3 = 3          # Convolution filters are 3 x 3 pixels.
num_filters3 = 48         # There are 48 of these filters.
conv_stride3=[1,2,2,1]
# Fully-connected layer.
fc_size = 160             # Number of neurons in fully-connected layer.
# Out:
# 1581

# %%
def variable_summaries(var):
    """Attach a lot of summaries to a Tensor (for TensorBoard visualization)."""
    with tf.name_scope('summaries'):
      mean = tf.reduce_mean(var)
      tf.summary.scalar('mean', mean)
      with tf.name_scope('stddev'):
        stddev = tf.sqrt(tf.reduce_mean(tf.square(var - mean)))
      tf.summary.scalar('stddev', stddev)
      tf.summary.scalar('max', tf.reduce_max(var))
      tf.summary.scalar('min', tf.reduce_min(var))
      tf.summary.histogram('histogram', var)

def new_weights(shape):
    return tf.Variable(tf.truncated_normal(shape, stddev=0.05))
def new_biases(length):
    return tf.Variable(tf.constant(0.05, shape=[length]))
def new_conv_layer(name,input,              # The previous layer.
                   num_input_channels, # Num. channels in prev. layer.
                   filter_size,        # Width and height of each filter.
                   num_filters,        # Number of filters.
                   list_strides,
                   use_pooling=True     # Use 2x2 max-pooling.
                   ): 

    with tf.name_scope(name):
        # Shape of the filter-weights for the convolution.
        # This format is determined by the TensorFlow API.
        shape = [filter_size, filter_size, num_input_channels, num_filters]
        # Create new weights aka. filters with the given shape.
        with tf.name_scope('ConvWeights'):
            weights = new_weights(shape=shape)
            variable_summaries(weights)
        # Create new biases, one for each filter.
        with tf.name_scope('ConvBiases'):
            biases = new_biases(length=num_filters)
            variable_summaries(weights)
        # Create the TensorFlow operation for convolution.
        # Note the strides are set to 1 in all dimensions.
        # The first and last stride must always be 1,
        # because the first is for the image-number and
        # the last is for the input-channel.
        # But e.g. strides=[1, 2, 2, 1] would mean that the filter
        # is moved 2 pixels across the x- and y-axis of the image.
        # The padding is set to 'SAME' which means the input image
        # is padded with zeroes so the size of the output is the same.
        layer = tf.nn.conv2d(input=input,
                             filter=weights,
                             strides=list_strides,
                             padding='SAME',
                             use_cudnn_on_gpu=True)
        # Add the biases to the results of the convolution.
        # A bias-value is added to each filter-channel.
        layer += biases
        # Use pooling to down-sample the image resolution?
        if use_pooling:
            # This is 2x2 max-pooling, which means that we
            # consider 2x2 windows and select the largest value
            # in each window. Then we move 2 pixels to the next window.
            layer = tf.nn.max_pool(value=layer,
                               ksize=[1, 2, 2, 1],
                               strides=[1, 2, 2, 1],
                               padding='SAME')
        # Rectified Linear Unit (ReLU).
        # It calculates max(x, 0) for each input pixel x.
        # This adds some non-linearity to the formula and allows us
        # to learn more complicated functions.
        layer = tf.nn.relu(layer)

    # Note that ReLU is normally executed before the pooling,
    # but since relu(max_pool(x)) == max_pool(relu(x)) we can
    # save 75% of the relu-operations by max-pooling first.

    # We return both the resulting layer and the filter-weights
    # because we will plot the weights later.
    
    return layer, weights
 

def flatten_layer(layer):
    # Get the shape of the input layer.
    layer_shape = layer.get_shape()

    # The shape of the input layer is assumed to be:
    # layer_shape == [num_images, img_height, img_width, num_channels]

    # The number of features is: img_height * img_width * num_channels
    # We can use a function from TensorFlow to calculate this.
    num_features = layer_shape[1:4].num_elements()
    
    # Reshape the layer to [num_images, num_features].
    # Note that we just set the size of the second dimension
    # to num_features and the size of the first dimension to -1
    # which means the size in that dimension is calculated
    # so the total size of the tensor is unchanged from the reshaping.
    layer_flat = tf.reshape(layer, [-1, num_features])

    # The shape of the flattened layer is now:
    # [num_images, img_height * img_width * num_channels]

    # Return both the flattened layer and the number of features.
    return layer_flat, num_features
def new_fc_layer(name,input,          # The previous layer.
                 num_inputs,     # Num. inputs from prev. layer.
                 num_outputs,    # Num. outputs.
                 use_relu=True): # Use Rectified Linear Unit (ReLU)?

    with tf.name_scope(name):
        # Create new weights and biases.
        with tf.name_scope('Weights'):
            weights = new_weights(shape=[num_inputs, num_outputs])
            variable_summaries(weights)
        with tf.name_scope('Biases'):
            biases = new_biases(length=num_outputs)
            variable_summaries(biases)
        # Calculate the layer as the matrix multiplication of
        # the input and weights, and then add the bias-values.
        layer = tf.matmul(input, weights) + biases
        # Use ReLU?
        if use_relu:
            layer = tf.nn.relu(layer)

    return layer

# %%
x = tf.placeholder(tf.float32, shape=[None, image_size_flat], name='x')
x_image = tf.reshape(x, [-1, image_size, image_size, num_channels])
y_true = tf.placeholder(tf.int64, shape=[batch_size], name='y_true')
#y_true_cls = tf.argmax(y_true, dimension=1)
#Convolutional Layer 1
layer_conv1, weights_conv1 = \
    new_conv_layer('ConvLayer1',input=x_image,
                   num_input_channels=num_channels,
                   filter_size=filter_size1,
                   num_filters=num_filters1,
                   list_strides=conv_stride1,
                   use_pooling=True
                   )

# %%
layer_conv1
# Out:
# <tf.Tensor 'ConvLayer1/Relu:0' shape=(?, 50, 50, 16) dtype=float32>

# %%
#Convolutional Layer 2
layer_conv2, weights_conv2 = \
    new_conv_layer('ConvLayer2',input=layer_conv1,
                   num_input_channels=num_filters1,
                   filter_size=filter_size2,
                   num_filters=num_filters2,
                   list_strides=conv_stride2,
                   use_pooling=True
                   )

# %%
layer_conv2
# Out:
# <tf.Tensor 'ConvLayer2/Relu:0' shape=(?, 25, 25, 32) dtype=float32>

# %%
#Convolutional Layer 3
layer_conv3, weights_conv3 = \
    new_conv_layer('ConvLayer3',input=layer_conv2,
                   num_input_channels=num_filters2,
                   filter_size=filter_size3,
                   num_filters=num_filters3,
                   list_strides=conv_stride3,
                   use_pooling=True
                   )

# %%
layer_conv3
# Out:
# <tf.Tensor 'ConvLayer3/Relu:0' shape=(?, 7, 7, 48) dtype=float32>

# %%
#Flattening the Output of the Convolutional Layer 3
layer_flat, num_features = flatten_layer(layer_conv3)

# %%
layer_flat
# Out:
# <tf.Tensor 'Reshape_1:0' shape=(?, 2352) dtype=float32>

# %%
num_features
# Out:
# 2352

# %%
layer_fc1 = new_fc_layer(name='FCLayer1',input=layer_flat,
                         num_inputs=num_features,
                         num_outputs=fc_size,
                         use_relu=True)

# %%
layer_fc1
# Out:
# <tf.Tensor 'FCLayer1/Relu:0' shape=(?, 160) dtype=float32>

# %%
layer_fc2 = new_fc_layer(name='OutputLayer',input=layer_fc1,
                         num_inputs=fc_size,
                         num_outputs=num_labels,
                         use_relu=False)

# %%
layer_fc2
# Out:
# <tf.Tensor 'OutputLayer/add:0' shape=(?, 1581) dtype=float32>

# %%
y_pred = tf.nn.softmax(layer_fc2)
y_pred_cls = tf.argmax(y_pred, dimension=1)
with tf.name_scope('loss'):
    cross_entropy = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=layer_fc2,
                                                        labels=y_true)
    cost = tf.reduce_mean(cross_entropy)
tf.summary.scalar('loss', cost)
optimizer = tf.train.AdamOptimizer(learning_rate=alpha).minimize(cost)

with tf.name_scope('accuracy'):
    correct_prediction = tf.equal(y_pred_cls, y_true)
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
tf.summary.scalar('accuracy',accuracy)
# Out:
# <tf.Tensor 'accuracy_1:0' shape=() dtype=string>

# %% [markdown]
# # Plotting the Convolutional Weights

# %%
def plot_conv_weights(weights, input_channel=0):
    # Assume weights are TensorFlow ops for 4-dim variables
    # e.g. weights_conv1 or weights_conv2.
    
    # Retrieve the values of the weight-variables from TensorFlow.
    # A feed-dict is not necessary because nothing is calculated.
    w = session.run(weights)

    # Get the lowest and highest values for the weights.
    # This is used to correct the colour intensity across
    # the images so they can be compared with each other.
    w_min = np.min(w)
    w_max = np.max(w)

    # Number of filters used in the conv. layer.
    num_filters = w.shape[3]

    # Number of grids to plot.
    # Rounded-up, square-root of the number of filters.
    num_grids = math.ceil(math.sqrt(num_filters))
    
    # Create figure with a grid of sub-plots.
    fig, axes = plt.subplots(num_grids, num_grids)

    # Plot all the filter-weights.
    for i, ax in enumerate(axes.flat):
        # Only plot the valid filter-weights.
        if i<num_filters:
            # Get the weights for the i'th filter of the input channel.
            # See new_conv_layer() for details on the format
            # of this 4-dim tensor.
            img = w[:, :, input_channel, i]

            # Plot image.
            ax.imshow(img, vmin=w_min, vmax=w_max,
                      interpolation='nearest', cmap='seismic')
        
        # Remove ticks from the plot.
        ax.set_xticks([])
        ax.set_yticks([])
    
    # Ensure the plot is shown correctly with multiple plots
    # in a single Notebook cell.
    plt.show()

# %% [markdown]
# # Plotting the outputs of Convolutional Layer

# %%
def plot_conv_layer(layer, image):
    # Assume layer is a TensorFlow op that outputs a 4-dim tensor
    # which is the output of a convolutional layer,
    # e.g. layer_conv1 or layer_conv2.

    # Create a feed-dict containing just one image.
    # Note that we don't need to feed y_true because it is
    # not used in this calculation.
    feed_dict = {x: [image]}

    # Calculate and retrieve the output values of the layer
    # when inputting that image.
    values = session.run(layer, feed_dict=feed_dict)

    # Number of filters used in the conv. layer.
    num_filters = values.shape[3]

    # Number of grids to plot.
    # Rounded-up, square-root of the number of filters.
    num_grids = math.ceil(math.sqrt(num_filters))
    
    # Create figure with a grid of sub-plots.
    fig, axes = plt.subplots(num_grids, num_grids)

    # Plot the output images of all the filters.
    for i, ax in enumerate(axes.flat):
        # Only plot the images for valid filters.
        if i<num_filters:
            # Get the output image of using the i'th filter.
            # See new_conv_layer() for details on the format
            # of this 4-dim tensor.
            img = values[0, :, :, i]

            # Plot image.
            ax.imshow(img, interpolation='nearest', cmap='binary')
        
        # Remove ticks from the plot.
        ax.set_xticks([])
        ax.set_yticks([])
    
    # Ensure the plot is shown correctly with multiple plots
    # in a single Notebook cell.
    plt.show()
    return fig;

# %%
def accuracy_validation(predictions, labels):
    eq = (predictions == labels)
    return ((100.0 * np.sum(eq))/eq.size)

# %%
def run_validation(X_test):
    count = 0;
    result = [];
    for i in range(int(X_test.shape[0]/100)):
        result.extend(session.run(y_pred_cls,feed_dict={x:X_test[count:count+100]}))
        count = count+100;
    acc = accuracy_validation(y_test,result)
    print ('---> Validation Accuracy',acc)
    return acc

# %%
session=tf.Session()
session.run(tf.global_variables_initializer())
writer = tf.summary.FileWriter("friends/",session.graph)
summary=tf.summary.merge_all();
saver = tf.train.Saver();
save_dir = 'friends/'
save_path = os.path.join(save_dir, 'model')
saver.restore(sess=session, save_path=save_path)
save_dir = 'FaceModels/'
save_path = os.path.join(save_dir, 'model1')
print("Initialized")
"""
for val in range(51):
    (X_train,y_train,X_test,y_test)= d.getData()
    num_iterations = num_iterations+1000;
"""
offset=0
best = 0
for step in range(num_iterations):
    offset = (step * batch_size) % (X_train.shape[0] - batch_size)
    batch_data = X_train[offset:(offset + batch_size), :]
    batch_labels = y_train[offset:(offset + batch_size)]
    feed_dict = {x : batch_data, y_true : batch_labels}        
    _, l, acc,s = session.run([optimizer, cost, accuracy,summary],feed_dict=feed_dict)
    if ((step % 2000 == 0) or (step == num_iterations-1)):
        curr = run_validation(X_test);
        if(curr>best):
            best = curr;
            print (best)
            saver.save(session,save_path)
    if ((step % 500 == 0)or (step == num_iterations-1)):
        print("Minibatch loss at step %d: %f" % (step, l))
        print("mini batch accuracy: ", acc)            
        writer.add_summary(s,step)
        writer.flush()
print("Model saved in file: %s" % save_path)
print("done")
# Out:
# Initialized
# ---> Validation Accuracy 43.380952381
# 43.380952381
# Minibatch loss at step 0: 3.514338
# mini batch accuracy:  0.61
# ---> Validation Accuracy 31.4497354497
# Minibatch loss at step 500: 3.302698
# mini batch accuracy:  0.32
# ---> Validation Accuracy 36.9444444444
# Minibatch loss at step 1000: 2.829388
# mini batch accuracy:  0.44
# ---> Validation Accuracy 39.8650793651
# Minibatch loss at step 1500: 3.024311
# mini batch accuracy:  0.42
# ---> Validation Accuracy 41.5
# Minibatch loss at step 2000: 2.662807
# mini batch accuracy:  0.43
# ---> Validation Accuracy 43.2645502646
# Minibatch loss at step 2500: 3.125372
# mini batch accuracy:  0.4
# ---> Validation Accuracy 43.8068783069
# 43.8068783069
# Minibatch loss at step 3000: 2.498807
# mini batch accuracy:  0.52
# ---> Validation Accuracy 44.753968254
# 44.753968254
# Minibatch loss at step 3500: 2.649040
# mini batch accuracy:  0.49
# ---> Validation Accuracy 44.455026455
# Minibatch loss at step 4000: 2.310741
# mini batch accuracy:  0.52
# ---> Validation Accuracy 45.3306878307
# 45.3306878307
# Minibatch loss at step 4500: 2.473493
# mini batch accuracy:  0.53
# ---> Validation Accuracy 45.4444444444
# 45.4444444444
# Minibatch loss at step 5000: 2.561725
# mini batch accuracy:  0.5
# ---> Validation Accuracy 45.8227513228
# 45.8227513228
# Minibatch loss at step 5500: 2.556683
# mini batch accuracy:  0.46
# ---> Validation Accuracy 47.462962963
# 47.462962963
# Minibatch loss at step 6000: 2.099694
# mini batch accuracy:  0.54
# ---> Validation Accuracy 46.246031746
# Minibatch loss at step 6500: 3.009341
# mini batch accuracy:  0.39
# ---> Validation Accuracy 46.962962963
# Minibatch loss at step 7000: 2.560167
# mini batch accuracy:  0.56
# ---> Validation Accuracy 47.9576719577
# 47.9576719577
# Minibatch loss at step 7500: 2.653773
# mini batch accuracy:  0.49
# ---> Validation Accuracy 48.7830687831
# 48.7830687831
# Minibatch loss at step 8000: 2.342146
# mini batch accuracy:  0.52
# ---> Validation Accuracy 48.1164021164
# Minibatch loss at step 8500: 2.497804
# mini batch accuracy:  0.57
# ---> Validation Accuracy 47.5952380952
# Minibatch loss at step 9000: 2.221133
# mini batch accuracy:  0.59
# ---> Validation Accuracy 47.4470899471
# Minibatch loss at step 9500: 3.143315
# mini batch accuracy:  0.52
# ---> Validation Accuracy 48.3835978836
# Minibatch loss at step 10000: 2.426716
# mini batch accuracy:  0.52
# ---> Validation Accuracy 49.4788359788
# 49.4788359788
# Minibatch loss at step 10500: 2.275741
# mini batch accuracy:  0.52
# ---> Validation Accuracy 49.1666666667
# Minibatch loss at step 11000: 1.930113
# mini batch accuracy:  0.61
# ---> Validation Accuracy 48.8412698413
# Minibatch loss at step 11500: 2.404421
# mini batch accuracy:  0.59
# ---> Validation Accuracy 50.0396825397
# 50.0396825397
# Minibatch loss at step 12000: 2.139429
# mini batch accuracy:  0.6
# ---> Validation Accuracy 50.0
# Minibatch loss at step 12500: 2.241127
# mini batch accuracy:  0.53
# ---> Validation Accuracy 49.253968254
# Minibatch loss at step 13000: 2.228176
# mini batch accuracy:  0.54
# ---> Validation Accuracy 50.0687830688
# 50.0687830688
# Minibatch loss at step 13500: 2.148440
# mini batch accuracy:  0.54
# ---> Validation Accuracy 50.962962963
# 50.962962963
# Minibatch loss at step 14000: 2.373902
# mini batch accuracy:  0.52
# ---> Validation Accuracy 51.0052910053
# 51.0052910053
# Minibatch loss at step 14500: 1.928906
# mini batch accuracy:  0.6
# ---> Validation Accuracy 50.8201058201
# Minibatch loss at step 15000: 1.942806
# mini batch accuracy:  0.67
# ---> Validation Accuracy 49.0793650794
# Minibatch loss at step 15500: 1.981845
# mini batch accuracy:  0.63
# ---> Validation Accuracy 50.746031746
# Minibatch loss at step 16000: 1.826755
# mini batch accuracy:  0.61
# ---> Validation Accuracy 49.4470899471
# Minibatch loss at step 16500: 2.090974
# mini batch accuracy:  0.62
# ---> Validation Accuracy 51.0185185185
# 51.0185185185
# Minibatch loss at step 17000: 1.876402
# mini batch accuracy:  0.61
# ---> Validation Accuracy 50.6481481481
# Minibatch loss at step 17500: 2.216980
# mini batch accuracy:  0.62
# ---> Validation Accuracy 50.9708994709
# Minibatch loss at step 18000: 2.493519
# mini batch accuracy:  0.57
# ---> Validation Accuracy 51.0343915344
# 51.0343915344
# Minibatch loss at step 18500: 2.316836
# mini batch accuracy:  0.55
# ---> Validation Accuracy 49.5687830688
# Minibatch loss at step 19000: 2.417041
# mini batch accuracy:  0.57
# ---> Validation Accuracy 51.119047619
# 51.119047619
# Minibatch loss at step 19500: 2.071719
# mini batch accuracy:  0.56
# ---> Validation Accuracy 50.537037037
# Minibatch loss at step 20000: 2.422893
# mini batch accuracy:  0.49
# ---> Validation Accuracy 50.828042328
# Minibatch loss at step 20500: 2.257737
# mini batch accuracy:  0.56
# ---> Validation Accuracy 51.4153439153
# 51.4153439153
# Minibatch loss at step 21000: 1.967201
# mini batch accuracy:  0.63
# ---> Validation Accuracy 49.8068783069
# Minibatch loss at step 21500: 2.171635
# mini batch accuracy:  0.54
# ---> Validation Accuracy 51.6137566138
# 51.6137566138
# Minibatch loss at step 22000: 1.727898
# mini batch accuracy:  0.61
# ---> Validation Accuracy 51.3465608466
# Minibatch loss at step 22500: 3.003191
# mini batch accuracy:  0.52
# ---> Validation Accuracy 51.1402116402
# Minibatch loss at step 23000: 1.819456
# mini batch accuracy:  0.63
# ---> Validation Accuracy 51.6164021164
# 51.6164021164
# Minibatch loss at step 23500: 2.041031
# mini batch accuracy:  0.6
# ---> Validation Accuracy 51.664021164
# 51.664021164
# Minibatch loss at step 24000: 2.223766
# mini batch accuracy:  0.61
# ---> Validation Accuracy 52.1481481481
# 52.1481481481
# Minibatch loss at step 24500: 2.214477
# mini batch accuracy:  0.61
# ---> Validation Accuracy 52.0132275132
# Minibatch loss at step 25000: 2.098821
# mini batch accuracy:  0.6
# ---> Validation Accuracy 51.1375661376
# Minibatch loss at step 25500: 1.961878
# mini batch accuracy:  0.66
# ---> Validation Accuracy 52.6058201058
# 52.6058201058
# Minibatch loss at step 26000: 1.686595
# mini batch accuracy:  0.63
# ---> Validation Accuracy 51.4338624339
# Minibatch loss at step 26500: 2.041045
# mini batch accuracy:  0.61
# ---> Validation Accuracy 51.2169312169
# Minibatch loss at step 27000: 2.016739
# mini batch accuracy:  0.59
# ---> Validation Accuracy 52.1402116402
# Minibatch loss at step 27500: 2.461976
# mini batch accuracy:  0.57
# ---> Validation Accuracy 51.9391534392
# Minibatch loss at step 28000: 1.511231
# mini batch accuracy:  0.71
# ---> Validation Accuracy 52.1825396825
# Minibatch loss at step 28500: 2.180940
# mini batch accuracy:  0.64
# ---> Validation Accuracy 50.7645502646
# Minibatch loss at step 29000: 1.810561
# mini batch accuracy:  0.63
# ---> Validation Accuracy 51.582010582
# Minibatch loss at step 29500: 1.823669
# mini batch accuracy:  0.64
# ---> Validation Accuracy 51.791005291
# Minibatch loss at step 30000: 1.903791
# mini batch accuracy:  0.61
# ---> Validation Accuracy 51.8783068783
# Minibatch loss at step 30500: 1.596596
# mini batch accuracy:  0.67
# ---> Validation Accuracy 52.1084656085
# Minibatch loss at step 31000: 1.844327
# mini batch accuracy:  0.63
# ---> Validation Accuracy 51.6693121693
# Minibatch loss at step 31500: 1.834952
# mini batch accuracy:  0.6
# ---> Validation Accuracy 52.3492063492
# Minibatch loss at step 32000: 2.624132
# mini batch accuracy:  0.48
# ---> Validation Accuracy 51.2566137566
# Minibatch loss at step 32500: 2.012817
# mini batch accuracy:  0.63
# ---> Validation Accuracy 52.8148148148
# 52.8148148148
# Minibatch loss at step 33000: 1.627834
# mini batch accuracy:  0.66
# ---> Validation Accuracy 52.0687830688
# Minibatch loss at step 33500: 1.935200
# mini batch accuracy:  0.63
# ---> Validation Accuracy 50.6216931217
# Minibatch loss at step 34000: 1.542374
# mini batch accuracy:  0.69
# ---> Validation Accuracy 52.2486772487
# Minibatch loss at step 34500: 1.874112
# mini batch accuracy:  0.65
# ---> Validation Accuracy 51.6455026455
# Minibatch loss at step 35000: 2.000286
# mini batch accuracy:  0.6
# ---> Validation Accuracy 52.9047619048
# 52.9047619048
# Minibatch loss at step 35500: 2.069124
# mini batch accuracy:  0.59
# ---> Validation Accuracy 51.4761904762
# Minibatch loss at step 36000: 2.358073
# mini batch accuracy:  0.56
# ---> Validation Accuracy 52.3227513228
# Minibatch loss at step 36500: 1.508820
# mini batch accuracy:  0.72
# ---> Validation Accuracy 52.2354497354
# Minibatch loss at step 37000: 2.089406
# mini batch accuracy:  0.58
# ---> Validation Accuracy 52.0132275132
# Minibatch loss at step 37500: 1.361388
# mini batch accuracy:  0.7
# ---> Validation Accuracy 52.037037037
# Minibatch loss at step 38000: 2.050516
# mini batch accuracy:  0.63
# ---> Validation Accuracy 52.4682539683
# Minibatch loss at step 38500: 1.798520
# mini batch accuracy:  0.64
# ---> Validation Accuracy 52.455026455
# Minibatch loss at step 39000: 2.248265
# mini batch accuracy:  0.57
# ---> Validation Accuracy 51.962962963
# Minibatch loss at step 39500: 2.059707
# mini batch accuracy:  0.61
# ---> Validation Accuracy 51.2566137566
# Minibatch loss at step 40000: 2.050789
# mini batch accuracy:  0.63
# ---> Validation Accuracy 52.4523809524
# Minibatch loss at step 40500: 1.943494
# mini batch accuracy:  0.59
# ---> Validation Accuracy 51.537037037
# Minibatch loss at step 41000: 1.335835
# mini batch accuracy:  0.68
# ---> Validation Accuracy 51.6243386243
# Minibatch loss at step 41500: 2.156488
# mini batch accuracy:  0.6
# ---> Validation Accuracy 52.6878306878
# Minibatch loss at step 42000: 1.588402
# mini batch accuracy:  0.64
# ---> Validation Accuracy 52.1296296296
# Minibatch loss at step 42500: 1.743628
# mini batch accuracy:  0.65
# ---> Validation Accuracy 51.3439153439
# Minibatch loss at step 43000: 1.445410
# mini batch accuracy:  0.73
# ---> Validation Accuracy 53.1084656085
# 53.1084656085
# Minibatch loss at step 43500: 1.833967
# mini batch accuracy:  0.59
# ---> Validation Accuracy 52.0
# Minibatch loss at step 44000: 1.587049
# mini batch accuracy:  0.67
# ---> Validation Accuracy 49.9735449735
# Minibatch loss at step 44500: 1.743562
# mini batch accuracy:  0.65
# ---> Validation Accuracy 52.1666666667
# Minibatch loss at step 45000: 1.706474
# mini batch accuracy:  0.66
# ---> Validation Accuracy 51.5185185185
# Minibatch loss at step 45500: 1.440314
# mini batch accuracy:  0.67
# ---> Validation Accuracy 50.0661375661
# Minibatch loss at step 46000: 2.064433
# mini batch accuracy:  0.53
# ---> Validation Accuracy 51.7380952381
# Minibatch loss at step 46500: 1.732007
# mini batch accuracy:  0.63
# ---> Validation Accuracy 51.8915343915
# Minibatch loss at step 47000: 1.981614
# mini batch accuracy:  0.69
# ---> Validation Accuracy 51.4285714286
# Minibatch loss at step 47500: 1.294580
# mini batch accuracy:  0.74
# ---> Validation Accuracy 51.6164021164
# Minibatch loss at step 48000: 1.591199
# mini batch accuracy:  0.69
# ---> Validation Accuracy 52.5238095238
# Minibatch loss at step 48500: 1.692410
# mini batch accuracy:  0.69
# ---> Validation Accuracy 51.7275132275
# Minibatch loss at step 49000: 1.745023
# mini batch accuracy:  0.57
# ---> Validation Accuracy 52.1904761905
# Minibatch loss at step 49500: 1.696422
# mini batch accuracy:  0.64
# ---> Validation Accuracy 51.4417989418
# Minibatch loss at step 49999: 1.672113
# mini batch accuracy:  0.61
# Model saved in file: FaceModels/model1
# done

# %% [markdown]
# # Filters of Convolutional Layer 1(red is closer to maximum, blue is closer to minimum)

# %%
plot_conv_weights(weights=weights_conv1)

# %% [markdown]
# # Filters of Convolutional Layer 2

# %%
plot_conv_weights(weights=weights_conv2,input_channel=0)
plot_conv_weights(weights=weights_conv2,input_channel=1)

# %% [markdown]
# # Filters of Convolutional Layer 3

# %%
plot_conv_weights(weights=weights_conv3,input_channel=0)
plot_conv_weights(weights=weights_conv3,input_channel=1)
plot_conv_weights(weights=weights_conv3,input_channel=2)

# %%
for i in range(0,len(train_data_X[:10])):
    print(train_data_Y[i])
    print(directory[train_data_Y[i]])
    plt.imshow(train_data_X[i],cmap='gray');
    plt.show();
# Out:
# 938
# leighton meester
# 6
# abraham lincoln
# 1292
# robert downey
# 399
# don bosco
# 211
# bridget moynahan
# 16
# adrien brody
# 1266
# raven symone
# 954
# lindsay lohan
# 577
# halle berry
# 1216
# paz vega

# %%
#Puts the Convolution Plots into a directory
def print_convImage(layer,image,name):
    directory = 'Convolution/Images/'+str(layer.name.split('/')[0])
    if not os.path.exists(directory):#if directory is not available, creates a new directory.
        os.makedirs(directory)
    fig = plot_conv_layer(layer=layer,image=image)
    fig.savefig(directory+'/'+str(name)+'.png');

# %%
for i in range(10):
    print('Image',i)
    print_convImage(layer=layer_conv1,image=X_train[i],name=i)
# Out:
# Image 0
# Image 1
# Image 2
# Image 3
# Image 4
# Image 5
# Image 6
# Image 7
# Image 8
# Image 9

# %%
for i in range(10):
    print('Image',i)
    print_convImage(layer=layer_conv2,image=X_train[i],name=i)
# Out:
# Image 0
# Image 1
# Image 2
# Image 3
# Image 4
# Image 5
# Image 6
# Image 7
# Image 8
# Image 9

# %%
for i in range(10):
    print('Image',i)
    print_convImage(layer=layer_conv3,image=X_train[i],name=i)
# Out:
# Image 0
# Image 1
# Image 2
# Image 3
# Image 4
# Image 5
# Image 6
# Image 7
# Image 8
# Image 9

# %%
session = tf.Session()
saver = tf.train.Saver();
save_dir = 'FaceModels'
save_path = os.path.join(save_dir, 'model1')
saver.restore(sess=session, save_path=save_path)

face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_alt2.xml')
cnt= 0;
APPROX = 10;
pixel=100

images = os.listdir("test");
l = len(images)

test_data = np.zeros([l,100,100])

for i in images:
    img = cv2.imread('test/'+i,0);
    faces = face_cascade.detectMultiScale(img, 1.3, 5)
    for (x1,y,w,h) in faces:
        roi_gray = np.array(img[y-APPROX:y+h+APPROX, x1-APPROX:x1+w+APPROX],dtype=float)
        img = cv2.resize(roi_gray, (pixel, pixel))
        test_data[cnt] = (img-img.min())/(img.max()-img.min());
        cnt = cnt+1
        break;
        
[recognized,val] = session.run([y_pred_cls,y_pred],feed_dict={x:test_data.reshape(l,100*100)})
for i in range(l):
    if val[i].max() > 0.3:
        print(val.max())
        print(directory[int(recognized[i])])
    plt.imshow(test_data[i],cmap='gray')
    plt.show()
# Out:
# 0.999906
# bill gates
# 0.999906
# brad pitt
# 0.999906
# steve jobs

# %%
# Out:
# steve jobs

# %%
val = session.run(y_pred,feed_dict={x:test_data.reshape(l,100*100)})
print(val)
# Out:
# [[  6.68773170e-09   1.04136567e-10   1.36435156e-12 ...,   6.11098498e-12
#     1.18952209e-10   5.24185903e-12]
#  [  1.15101640e-04   1.95108718e-04   1.41146339e-09 ...,   3.14200292e-08
#     9.08421047e-11   2.80327572e-06]
#  [  6.02087689e-14   1.39369105e-09   4.98551157e-12 ...,   1.45645115e-19
#     2.77322297e-14   2.27116792e-09]
#  [  1.28916020e-06   2.68115651e-11   1.24383170e-08 ...,   9.13336695e-09
#     1.95686178e-09   4.28941848e-13]]

# %%
for i in range(l):
    print(val[i].max())
# Out:
# 0.999856
# 0.202957
# 0.999906
# 0.9794

# %%
session.close()
print(tf.__version__)
